# %% [markdown]
# Index Map
#
# 0.   Element Number
# 1.   Name
# 2.   Weight
# 3.   State at 0 C
# 4.   Series
# 5.   Electronegativity
#
# If a value doesn't exist, 'Unknown' is placed there instead.
#
#
# The list of values can have new data points added to it as I expand the library.

# %%
periodic_table = {
    
    'H': [1, 'Hydrogen', 1.008, 'Gas', 'Reactive nonmetals', 2.20],
    'He': [2, 'Helium', 4.0026, 'Gas', 'Noble gases', None],
    'Li': [3, 'Lithium', 6.94, 'Solid', 'Alkali metals', 0.98],
    'Be': [4, 'Beryllium', 9.0122, 'Solid', 'Alkaline earth metals', 1.57],
    'B': [5, 'Boron', 10.81, 'Solid', 'Metalloids', 2.04],
    'C': [6, 'Carbon', 12.011, 'Solid', 'Reactive nonmetals', 2.55],
    'N': [7, 'Nitrogen', 14.007, 'Gas', 'Reactive nonmetals', 3.04],
    'O': [8, 'Oxygen', 15.999, 'Gas', 'Reactive nonmetals', 3.44],
    'F': [9, 'Fluorine', 18.998, 'Gas', 'Reactive nonmetals', 3.98],
    'Ne': [10, 'Neon', 20.180, 'Gas', 'Noble gases', None],
    'Na': [11, 'Sodium', 22.990, 'Solid', 'Alkali metals', 0.93],
    'Mg': [12, 'Magnesium', 24.305, 'Solid', 'Alkaline earth metals', 1.31],
    'Al': [13, 'Aluminium', 26.982, 'Solid', 'Post-transition metals', 1.61],
    'Si': [14, 'Silicon', 28.085, 'Solid', 'Metalloids', 1.90],
    'P': [15, 'Phosphorus', 30.974, 'Solid', 'Reactive nonmetals', 2.19],
    'S': [16, 'Sulfur', 32.06, 'Solid', 'Reactive nonmetals', 2.58],
    'Cl': [17, 'Chlorine', 35.45, 'Gas', 'Reactive nonmetals', 3.16],
    'Ar': [18, 'Argon', 39.948, 'Gas', 'Noble gases', None],
    'K': [19, 'Potassium', 39.098, 'Solid', 'Alkali metals', 0.82],
    'Ca': [20, 'Calcium', 40.078, 'Solid', 'Alkaline earth metals', 1.0],
    'Sc': [21, 'Scandium', 44.956, 'Solid', 'Transition metals', 1.36],
    'Ti': [22, 'Titanium', 47.867, 'Solid', 'Transition metals', 1.54],
    'V': [23, 'Vanadium', 50.942, 'Solid', 'Transition metals', 1.63],
    'Cr': [24, 'Chromium', 51.996, 'Solid', 'Transition metals', 1.66],
    'Mn': [25, 'Manganese', 54.938, 'Solid', 'Transition metals', 1.55],
    'Fe': [26, 'Iron', 55.845, 'Solid', 'Transition metals', 1.83],
    'Co': [27, 'Cobalt', 58.933, 'Solid', 'Transition metals', 1.88],
    'Ni': [28, 'Nickel', 58.693, 'Solid', 'Transition metals', 1.91],
    'Cu': [29, 'Copper', 63.546, 'Solid', 'Transition metals', 1.90],
    'Zn': [30, 'Zinc', 65.38, 'Solid', 'Transition metals', 1.65],
    'Ga': [31, 'Gallium', 69.723, 'Solid', 'Post-transition metals', 1.81],
    'Ge': [32, 'Germanium', 72.630, 'Solid', 'Metalloids', 2.01],
    'As': [33, 'Arsenic', 74.922, 'Solid', 'Metalloids', 2.18],
    'Se': [34, 'Selenium', 78.971, 'Solid', 'Reactive nonmetals', 2.55],
    'Br': [35, 'Bromine', 79.904, 'Liquid', 'Reactive nonmetals', 2.96],
    'Kr': [36, 'Krypton', 83.798, 'Gas', 'Noble gases', 3.0],
    'Rb': [37, 'Rubidium', 85.468, 'Solid', 'Alkali metals', 0.82],
    'Sr': [38, 'Strontium', 87.62, 'Solid', 'Alkaline earth metals', 0.95],
    'Y': [39, 'Yttrium', 88.906, 'Solid', 'Transition metals', 1.22],
    'Zr': [40, 'Zirconium', 91.224, 'Solid', 'Transition metals', 1.33],
    'Nb': [41, 'Niobium', 92.906, 'Solid', 'Transition metals', 1.6],
    'Mo': [42, 'Molybdenum', 95.95, 'Solid', 'Transition metals', 2.16],
    'Tc': [43, 'Technetium', 98, 'Solid', 'Transition metals', 1.9],
    'Ru': [44, 'Ruthenium', 101.07, 'Solid', 'Transition metals', 2.2],
    'Rh': [45, 'Rhodium', 102.91, 'Solid', 'Transition metals', 2.28],
    'Pd': [46, 'Palladium', 106.42, 'Solid', 'Transition metals', 2.20],
    'Ag': [47, 'Silver', 107.87, 'Solid', 'Transition metals', 1.93],
    'Cd': [48, 'Cadmium', 112.41, 'Solid', 'Transition metals', 1.69],
    'In': [49, 'Indium', 114.82, 'Solid', 'Post-transition metals', 1.78],
    'Sn': [50, 'Tin', 118.71, 'Solid', 'Post-transition metals', 1.96],
    'Sb': [51, 'Antimony', 121.76, 'Solid', 'Metalloids', 2.05],
    'Te': [52, 'Tellurium', 127.60, 'Solid', 'Metalloids', 2.1],
    'I': [53, 'Iodine', 126.90, 'Solid', 'Reactive nonmetals', 2.66],
    'Xe': [54, 'Xenon', 131.29, 'Gas', 'Noble gases', 2.6],
    'Cs': [55, 'Caesium', 132.91, 'Solid', 'Alkali metals', 0.79],
    'Ba': [56, 'Barium', 137.33, 'Solid', 'Alkaline earth metals', 0.89],
    'La': [57, 'Lanthanum', 138.91, 'Solid', 'Lanthanoids', 1.10],
    'Ce': [58, 'Cerium', 140.12, 'Solid', 'Lanthanoids', 1.12],
    'Pr': [59, 'Praseodymium', 140.91, 'Solid', 'Lanthanoids', 1.13],
    'Nd': [60, 'Neodymium', 144.24, 'Solid', 'Lanthanoids', 1.14],
    'Pm': [61, 'Promethium', 145, 'Solid', 'Lanthanoids', None],
    'Sm': [62, 'Samarium', 150.36, 'Solid', 'Lanthanoids', 1.17],
    'Eu': [63, 'Europium', 151.96, 'Solid', 'Lanthanoids', None],
    'Gd': [64, 'Gadolinium', 157.25, 'Solid', 'Lanthanoids', 1.20],
    'Tb': [65, 'Terbium', 158.93, 'Solid', 'Lanthanoids', None],
    'Dy': [66, 'Dysprosium', 162.50, 'Solid', 'Lanthanoids', 1.22],
    'Ho': [67, 'Holmium', 164.93, 'Solid', 'Lanthanoids', 1.23],
    'Er': [68, 'Erbium', 167.26, 'Solid', 'Lanthanoids', 1.24],
    'Tm': [69, 'Thulium', 168.93, 'Solid', 'Lanthanoids', 1.25],
    'Yb': [70, 'Ytterbium', 173.05, 'Solid', 'Lanthanoids', None],
    'Lu': [71, 'Lutetium', 174.97, 'Solid', 'Lanthanoids', 1.27],
    'Hf': [72, 'Hafnium', 178.49, 'Solid', 'Transition metals', 1.3],
    'Ta': [73, 'Tantalum', 180.95, 'Solid', 'Transition metals', 1.5],
    'W': [74, 'Tungsten', 183.84, 'Solid', 'Transition metals', 2.36],
    'Re': [75, 'Rhenium', 186.21, 'Solid', 'Transition metals', 1.9],
    'Os': [76, 'Osmium', 190.23, 'Solid', 'Transition metals', 2.2],
    'Ir': [77, 'Iridium', 192.22, 'Solid', 'Transition metals', 2.20],
    'Pt': [78, 'Platinum', 195.08, 'Solid', 'Transition metals', 2.28],
    'Au': [79, 'Gold', 196.97, 'Solid', 'Transition metals', 2.54],
    'Hg': [80, 'Mercury', 200.59, 'Solid', 'Transition metals', 2.0],
    'Tl': [81, 'Thallium', 204.38, 'Solid', 'Post-transition metals', 1.62],
    'Pb': [82, 'Lead', 207.2, 'Solid', 'Post-transition metals', 2.33],
    'Bi': [83, 'Bismuth', 208.98, 'Solid', 'Post-transition metals', 2.02],
    'Po': [84, 'Polonium', 209, 'Solid', 'Post-transition metals', 2.0],
    'At': [85, 'Astatine', 210, 'Solid', 'Metalloids', 2.2],
    'Rn': [86, 'Radon', 222, 'Gas', 'Noble gases', None],
    'Fr': [87, 'Francium', 223, 'Solid', 'Alkali metals', 0.7],
    'Ra': [88, 'Radium', 226, 'Solid', 'Alkaline earth metals', 0.9],
    'Ac': [89, 'Actinium', 227, 'Solid', 'Actinoids', 1.1],
    'Th': [90, 'Thorium', 232.04, 'Solid', 'Actinoids', 1.3],
    'Pa': [91, 'Proctactinium', 231.04, 'Solid', 'Actinoids', 1.5],
    'U': [92, 'Uranium', 238.03, 'Solid', 'Actinoids', 1.38],
    'Np': [93, 'Neptunium', 237, 'Solid', 'Actinoids', 1.36],
    'Pu': [94, 'Plutonium', 244, 'Solid', 'Actinoids', 1.28],
    'Am': [95, 'Americium', 243, 'Solid', 'Actinoids', 1.3],
    'Cm': [96, 'Curium', 247, 'Solid', 'Actinoids', 1.3],
    'Bk': [97, 'Berkelium', 247, 'Solid', 'Actinoids', 1.3],
    'Cf': [98, 'Californium', 251, 'Solid', 'Actinoids', 1.3],
    'Es': [99, 'Einsteinium', 252, 'Solid', 'Actinoids', 1.3],
    'Fm': [100, 'Fermium', 257, 'Solid', 'Actinoids', 1.3],
    'Md': [101, 'Mendelevium', 258, 'Solid', 'Actinoids', 1.3],
    'No': [102, 'Nobelium', 259, 'Solid', 'Actinoids', 1.3],
    'Lr': [103, 'Lawrencium', 266, 'Solid', 'Actinoids', None],
    'Rf': [104, 'Rutherfordium', 267, 'Unknown', 'Transition metals', None],
    'Db': [105, 'Dubnium', 268, 'Unknown', 'Transition metals', None],
    'Sg': [106, 'Seaborgium', 269, 'Unknown', 'Transition metals', None],
    'Bh': [107, 'Bohrium', 270, 'Unknown', 'Transition metals', None],
    'Hs': [108, 'Hassium', 277, 'Unknown', 'Transition metals', None],
    'Mt': [109, 'Meitnerium', 278, 'Unknown', 'Unknown', None],
    'Ds': [110, 'Darmstadtium', 281, 'Unknown', 'Unknown', None],
    'Rg': [111, 'Roentgenium', 282, 'Unknown', 'Unknown', None],
    'Cn': [112, 'Copernicium', 285, 'Unknown', 'Unknown', None],
    'Nh': [113, 'Nihonium', 286, 'Unknown', 'Unknown', None],
    'Fl': [114, 'Flerovium', 289, 'Unknown', 'Unknown', None],
    'Mc': [115, 'Moscovium', 290, 'Unknown', 'Unknown', None],
    'Lv': [116, 'Livermorium', 293, 'Unknown', 'Unknown', None],
    'Ts': [117, 'Tennessine', 294, 'Unknown', 'Unknown', None],
    'Og': [118, 'Oganesson', 294, 'Unknown', 'Unknown', None]

}
